# %%
# Libraries
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("BankChurners.csv")
data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
Object_col =[]
for i in data.columns:
    if data[i].dtypes == 'O':
        Object_col.append(i)
Object_col
# Out:
# ['Attrition_Flag',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']

# %%
ax1 = sns.displot(x = data['Attrition_Flag'])
ax1.set(title = 'The Number Attrition of Customer')

ax2 = sns.displot(x = data['Gender'])
ax2.set(title = 'The Gender of Customer')


ax3 = sns.displot(x = data['Education_Level'].sort_values(ascending= True))
ax3.set(title = 'The Category of Education Level')
plt.xticks(rotation=90)

ax4 = sns.displot(x = data['Marital_Status'])
ax4.set(title = 'The Marital Status of Customer')

ax5 = sns.displot(x = data['Income_Category'].sort_values(ascending= False))
ax5.set(title = 'The Category of Customer Income')
plt.xticks(rotation=90)

ax6 = sns.displot(x = data['Card_Category'])
ax6.set(title = 'The Category of Card')


plt.show()

# %%
data.loc[(data['Attrition_Flag'] == 'Existing Customer'), 'Customer_group'] = 0
data.loc[(data['Attrition_Flag'] == 'Attrited Customer'), 'Customer_group'] = 1

data[['Attrition_Flag','Customer_group']].value_counts()
# Out:
# Attrition_Flag     Customer_group
# Existing Customer  0.0               8500
# Attrited Customer  1.0               1627
# dtype: int64

# %%
data.loc[(data['Gender'] == 'M'), 'Gender_group'] = 0
data.loc[(data['Gender'] == 'F'), 'Gender_group'] = 1

data[['Gender','Gender_group']].value_counts()
# Out:
# Gender  Gender_group
# F       1.0             5358
# M       0.0             4769
# dtype: int64

# %%
data.loc[(data['Education_Level'] == 'Unknown'), 'Education_group']       = 0
data.loc[(data['Education_Level'] == 'Uneducated'), 'Education_group']    = 1
data.loc[(data['Education_Level'] == 'High School'), 'Education_group']   = 2
data.loc[(data['Education_Level'] == 'College'), 'Education_group']       = 3
data.loc[(data['Education_Level'] == 'Post-Graduate'), 'Education_group'] = 4
data.loc[(data['Education_Level'] == 'Graduate'), 'Education_group']      = 5
data.loc[(data['Education_Level'] == 'Doctorate'), 'Education_group']     = 6

data[['Education_Level','Education_group']].value_counts()
# Out:
# Education_Level  Education_group
# Graduate         5.0                3128
# High School      2.0                2013
# Unknown          0.0                1519
# Uneducated       1.0                1487
# College          3.0                1013
# Post-Graduate    4.0                 516
# Doctorate        6.0                 451
# dtype: int64

# %%
data.loc[(data['Marital_Status'] == 'Unknown'), 'Marital_group']   = 0
data.loc[(data['Marital_Status'] == 'Single'), 'Marital_group']    = 1
data.loc[(data['Marital_Status'] == 'Married'), 'Marital_group']   = 2
data.loc[(data['Marital_Status'] == 'Divorced'), 'Marital_group']  = 3

data[['Marital_Status','Marital_group']].value_counts()
# Out:
# Marital_Status  Marital_group
# Married         2.0              4687
# Single          1.0              3943
# Unknown         0.0               749
# Divorced        3.0               748
# dtype: int64

# %%
data.loc[(data['Income_Category'] == 'Unknown'), 'Income_group']        = 0
data.loc[(data['Income_Category'] == 'Less than $40K'), 'Income_group'] = 1
data.loc[(data['Income_Category'] == '$40K - $60K'), 'Income_group']    = 2
data.loc[(data['Income_Category'] == '$60K - $80K'), 'Income_group']    = 3
data.loc[(data['Income_Category'] == '$80K - $120K'), 'Income_group']   = 4
data.loc[(data['Income_Category'] == '$120K +'), 'Income_group']        = 5

data[['Income_Category','Income_group']].value_counts()
# Out:
# Income_Category  Income_group
# Less than $40K   1.0             3561
# $40K - $60K      2.0             1790
# $80K - $120K     4.0             1535
# $60K - $80K      3.0             1402
# Unknown          0.0             1112
# $120K +          5.0              727
# dtype: int64

# %%
data.loc[(data['Card_Category'] == 'Blue'), 'Card_group']   = 0
data.loc[(data['Card_Category'] == 'Silver'), 'Card_group']    = 1
data.loc[(data['Card_Category'] == 'Gold'), 'Card_group']   = 2
data.loc[(data['Card_Category'] == 'Platinum'), 'Card_group']  = 3

data[['Card_Category','Card_group']].value_counts()
# Out:
# Card_Category  Card_group
# Blue           0.0           9436
# Silver         1.0            555
# Gold           2.0            116
# Platinum       3.0             20
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 29 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
data2 = data.drop(['CLIENTNUM','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis=1)
#data2 = data.drop(['CLIENTNUM'], axis=1)
data2.corr()
# Out:
# C:\Users\z004mbjn\AppData\Local\Temp\ipykernel_14940\4206084804.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2.corr()
#                           Customer_Age  Dependent_count  Months_on_book  \
# Customer_Age                  1.000000        -0.122254        0.788912
# Dependent_count              -0.122254         1.000000       -0.103062
# Months_on_book                0.788912        -0.103062        1.000000
# Total_Relationship_Count     -0.010931        -0.039076       -0.009203
# Months_Inactive_12_mon        0.054361        -0.010768        0.074164
# Contacts_Count_12_mon        -0.018452        -0.040505       -0.010774
# Credit_Limit                  0.002476         0.068065        0.007507
# Total_Revolving_Bal           0.014780        -0.002688        0.008623
# ...

# %%
sns.set(rc = {'figure.figsize':(20,20)})
sns.heatmap(data=data2.corr(), annot=True)
# Out:
# C:\Users\z004mbjn\AppData\Local\Temp\ipykernel_14940\586977815.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=data2.corr(), annot=True)
# <AxesSubplot: >

# %%
X = data2.drop(['Customer_group', 'Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category'], axis =1)
y = data2['Customer_group']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size = 0.3)

# %%
X_train
# Out:
#       Customer_Age  Dependent_count  Months_on_book  Total_Relationship_Count  \
# 1062            58                4              45                         4
# 5712            46                4              33                         3
# 5126            41                2              31                         5
# 5595            51                2              36                         5
# 7736            43                3              36                         3
# ...            ...              ...             ...                       ...
# 2504            34                4              26                         3
# 8095            42                3              26                         1
# 3515            45                5              39                         3
# 6450            33                3              22                         5
# 867             54                4              49                         3
#
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# %%
GBC = GradientBoostingClassifier(learning_rate=0.1, max_features=4, subsample= 0.5, n_estimators= 200)
GBC.fit(X_train, y_train)
y_pred = GBC.predict(X_test)

# %%
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('F1_score:', f1_score(y_test, y_pred))
# Out:
# Accuracy score: 0.9697268838433696
# F1_score: 0.8997821350762527

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.title('XG-Boosting Classifier')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
